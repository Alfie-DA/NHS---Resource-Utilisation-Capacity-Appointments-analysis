# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # Course 2: Data Analytics using Python

# %% [markdown]
# ## 0) Assignment: Diagnostic Analysis using Python
#
# You’ll be working with real-world data to address a problem faced by the National Health Service (NHS). The analysis will require you to utilise Python to explore the available data, create visualisations to explore and communicate trends, and extract meaningful insights to inform decision-making. This Jupyter Notebook is the starting point and it is important to document all your decisions and observations to ensure that these are available as inputs to the technical report and business presentation that will form part of your submission.

# %% [markdown]
# ### A note for students using this template
# This Jupyter Notebook is a template you can use to complete the Course 2 assignment: Diagnostic Analysis using Python.
# Keep in mind the following points:
# - Using this template as your working document is optional, it is **not required** to use this template to complete the assignment.
# - The intention of the template is to provide suggestions regarding the structure and workflow that is expected and it follows the assignment activites throughout the course.
# - Refer to the guidance in the Assignment Activity pages for specific details.
# - The markup and comments in this template identify the key elements you need to complete before submitting the assignment.
# - Make this notebook your own by adding comments, cells, and content to reflect your analytical journey. You can add links, screenshots, or images to support your analysis, refine or clarify the questions, and change the workflow to suit your process. Important elements include:
#     - code comments
#     - Markdown cells with your observations, interpretation, and notes in anticipation of the technical report and business presentation.
# - All code output and visualisations should be functional and visible in the submitted Jupyter Notebook.
# - If you decide to use this template for your assignment, make a copy of the notebook and save it using the assignment naming convention: **LastName_FirstName_DA201_Assignment_Notebook.ipynb**.
# - Be sure to save frequent snapshots of your Jupyter Notebook to ensure that you can recover work if required.
#
#  > ***Markdown*** Remember to change cell types to `Markdown`. You can review [Markdown basics](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax) to find out how to add formatted text, links, and images to your notebook.
#
#
#  > ***Notebook state*** Remember that you will have to execute all the code in your notebook (from the start of the notebook to where you are currently working) every time you restart your Jupyter Notebook server or when working in a new session. Make sure that your notebook is in the correct state before continuing with the work for the current module.

# %% [markdown]
# #

# %% [markdown]
# ## 1) Assignment activity 1
# In the first module you are encouraged to explore the data and the provided template. You should also reflect on the scenario and use case and start to document your own interpretation of the business questions and how you will go about answering them.

# %% [markdown]
# ## Analytical approach.

# %% [markdown]
# This assignment seeks to understand the issues facing the NHS in the following areas:
# - utilisation of services
# - missed appointments (particularly GP appointments)
# - potential value of using Twitter (now X) as an external data source in solving some of this problems.

# %% [markdown]
# This section outlines the data sources and the methodology adopted to analyse the dataset. It also utilised both exploratory and explanatory data analysis.
#
# **Data Source**:
#
# In this report, two (2) main sources of data were utilised: Internal & External. The internal data comprised of three (3): actual_duration.csv, appointments_regional.csv and national_categories.xlsx and a complementary text in the form of metadata (metadata_nhs.text). The external data is obtained from Tweeter (tweets.csv).
#
# **Methodology**:
#
# The above data sources were imported into Jupyter Notebook by Pandas and appropriate python code snippets were used to store these data in DataFrames for ease of analysis. The DataFrames were then analysed for trends and insights using python code snippets. The code cells were annotated with the appropriate comments and markdown explanations. The relevant outputs from the python code snippets are then visualised to aid in identifying trends and insights contained within the dataset. Some of the charts types and the rationale behind their use include:
# - Lineplots – used to show trends over time. As the stakeholders are interested in determining how the system is performing across the relevant months of the study.
# - Barplots – used to show comparison between categories. With this the stakeholders can compare healthcare professionals are leading the services and which service settings are mostly preferred by users. Also, which hashtags get retweeted and liked/favourited to be termed as trending.
# - Boxplot – used to show spread and outliers. Even though technical stakeholders are mostly interested in boxplots, the business stakeholders of the NHS can also benefit from the insight that boxplots offer. Here, the NHS bosses can know which services or locations are extremely overloaded or completely underperforming which can inform decisions on resource reallocation.

# %% [markdown]
# **Some specific questions to explore include**
# - How many types of service settings and which is most preferred
# - How many appointments are booked per month
# - How many appointments are attended per day
# - How long does it take from date of booking to attending an appointment
# - Are there seasonal variations in service demands and which services are in high demands
# - Are there enough resources such as staff to cater for the increasing needs.
# - What healthcare topics are being discussed among the population that stakeholders need to take into consideration. Etc.

# %% [markdown]
# > ***Check*** that you have adequately satisfied the expectations of the current module and that you have added code comments as well as Markdown cells documenting your analytic journey and observations to satisfy the assessment criteria.

# %% [markdown]
# #

# %% [markdown]
# ## 2) Assignment activity 2
# **Basic exploration and descriptive statistics.**
# - Import the three indicated data sources and perform basic exploratory analysis including obtaining descriptive statistics.
# - Determine and comment on the quality, usefulness, and opportunities contained in the data sets.
# - Document initial observations and findings.
#
# Are there any comments regarding data quality or descriptive statistics worth noting for each of the data sets?
# Can you comment on other features (columns) that could potentially be useful in your analysis?

# %% [markdown]
# ### Prepare your workstation

# %%
# Import the necessary libraries.
import pandas as pd
import numpy as np

# Import other libraries if required. (Note that you can revisit this section in later modules.)
import seaborn as sns
import matplotlib.pyplot as plt


# Optional - Ignore warnings.
import warnings
warnings.filterwarnings('ignore')

# %%
# Import and sense-check 'actual_duration.csv' as ad.
ad = pd.read_csv('actual_duration.csv')

# %%
# View the DataFrame.
print(ad.shape)
print(ad.dtypes)
print(ad.columns)
ad.head()
# Out:
# (137793, 8)
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object
# Index(['sub_icb_location_code', 'sub_icb_location_ons_code',
#        'sub_icb_location_name', 'icb_ons_code', 'region_ons_code',
#        'appointment_date', 'actual_duration', 'count_of_appointments'],
#       dtype='object')
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# ...

# %%
# Check for missing values.
ad.isnull().sum()
# Out:
# sub_icb_location_code        0
# sub_icb_location_ons_code    0
# sub_icb_location_name        0
# icb_ons_code                 0
# region_ons_code              0
# appointment_date             0
# actual_duration              0
# count_of_appointments        0
# dtype: int64

# %% [markdown]
# The output shows that there are no missing values in any of the columns.
# But some values under the 'actual_duration' column have not  been accurately captured
# and this has been replaced by 'Unknown/Data Quality'. This is giving false indication there are no missing values.
# That is to say, there are no missed appointments, with actual duration of the appoitments recorded.

# %%
# Review metadata and descriptive statistics.
ad.describe()
# Out:
#        count_of_appointments
# count          137793.000000
# mean             1219.080011
# std              1546.902956
# min                 1.000000
# 25%               194.000000
# 50%               696.000000
# 75%              1621.000000
# max             15400.000000

# %%
# Import and sense-check 'appointments_regional.csv' as ar.
ar = pd.read_csv('appointments_regional.csv')

# %%
# View the DataFrame.
print(ar.shape)
print(ar.dtypes)
print(ar.columns)
ar.head()
# Out:
# (596821, 7)
# icb_ons_code                         object
# appointment_month                    object
# appointment_status                   object
# hcp_type                             object
# appointment_mode                     object
# time_between_book_and_appointment    object
# count_of_appointments                 int64
# dtype: object
# Index(['icb_ons_code', 'appointment_month', 'appointment_status', 'hcp_type',
#        'appointment_mode', 'time_between_book_and_appointment',
#        'count_of_appointments'],
#       dtype='object')
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# ...

# %%
# Check for missing values.
ar.isnull()
ar.isnull().sum()
# Out:
# icb_ons_code                         0
# appointment_month                    0
# appointment_status                   0
# hcp_type                             0
# appointment_mode                     0
# time_between_book_and_appointment    0
# count_of_appointments                0
# dtype: int64

# %%
# Review metadata and descriptive statistics.
ar.describe()
# Out:
#        count_of_appointments
# count          596821.000000
# mean             1244.601857
# std              5856.887042
# min                 1.000000
# 25%                 7.000000
# 50%                47.000000
# 75%               308.000000
# max            211265.000000

# %%
nc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  datetime64[ns]
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 49.9+ MB

# %%
# Import and sense-check 'national_categories.xlsx' as nc.
nc = pd.read_excel('national_categories.xlsx')

# %%
# View the DataFrame.
print(nc.shape)
print(nc.dtypes)
print(nc.columns)
nc.head()
# Out:
# (817394, 8)
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object
# Index(['appointment_date', 'icb_ons_code', 'sub_icb_location_name',
#        'service_setting', 'context_type', 'national_category',
#        'count_of_appointments', 'appointment_month'],
#       dtype='object')
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# ...

# %%
# Check for missing values.
nc.isnull().sum()
# Out:
# appointment_date         0
# icb_ons_code             0
# sub_icb_location_name    0
# service_setting          0
# context_type             0
# national_category        0
# count_of_appointments    0
# appointment_month        0
# dtype: int64

# %%
nc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  datetime64[ns]
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 49.9+ MB

# %%
# Review metadata and descriptive statistics.
nc.describe()
# Out:
#                     appointment_date  count_of_appointments
# count                         817394          817394.000000
# mean   2022-01-16 00:50:35.860796160             362.183684
# min              2021-08-01 00:00:00               1.000000
# 25%              2021-10-25 00:00:00               7.000000
# 50%              2022-01-18 00:00:00              25.000000
# 75%              2022-04-07 00:00:00             128.000000
# max              2022-06-30 00:00:00           16590.000000
# std                              NaN            1084.576600

# %%
nc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  datetime64[ns]
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 49.9+ MB

# %% [markdown]
# ### Exploration suggestions:
# Make sure to supplement the list with additional questions and observations that you have identified during modules 1 and 2.

# %% [markdown]
# **Question 1:** How many locations are there in the data set?

# %%
# Determine the number of locations.
def count_locations_value_counts(ad):
    
    location_counts = ad['sub_icb_location_name'].value_counts()
    return location_counts

# Call the function and store the result
location_counts = count_locations_value_counts(ad)

print('Count of locations:')
print(location_counts)
# Out:
# Count of locations:
# sub_icb_location_name
# NHS Norfolk and Waveney ICB - 26A                       1484
# NHS Kent and Medway ICB - 91Q                           1484
# NHS North West London ICB - W2U3Z                       1484
# NHS Bedfordshire Luton and Milton Keynes ICB - M1J4Y    1484
# NHS Greater Manchester ICB - 14L                        1484
#                                                         ...
# NHS Staffordshire and Stoke-on-Trent ICB - 05D          1051
# NHS South Yorkshire ICB - 03L                           1028
# NHS North East and North Cumbria ICB - 00P              1025
# NHS South Yorkshire ICB - 02P                           1022
# NHS Cheshire and Merseyside ICB - 01F                   1013
# Name: count, Length: 106, dtype: int64

# %% [markdown]
# **Question 2:** What are the five locations with the highest number of records?

# %%
# Determine the top five locations based on record count.
def top_five_locations(ad):
    top_locations = ad['sub_icb_location_name'].value_counts().head(5)
    return top_locations

top_locations = top_five_locations(ad)

print('Top 5 locations with highest number of records:')
print(top_locations)
# Out:
# Top 5 locations with highest number of records:
# sub_icb_location_name
# NHS Norfolk and Waveney ICB - 26A                       1484
# NHS Kent and Medway ICB - 91Q                           1484
# NHS North West London ICB - W2U3Z                       1484
# NHS Bedfordshire Luton and Milton Keynes ICB - M1J4Y    1484
# NHS Greater Manchester ICB - 14L                        1484
# Name: count, dtype: int64

# %% [markdown]
# **Question 3:** How many service settings, context types, national categories, and appointment statuses are there?

# %%
# Determine the number of service settings.
# This is to count number of unique service settings
num_settings = nc['service_setting'].nunique()

print('Number of service setting:',num_settings)
# Out:
# Number of service setting: 5

# %%
# This is a list of the service setting and their count
settings_count = nc['service_setting'].value_counts()

print('Service settings and counts:')
print(settings_count)
# Out:
# Service settings and counts:
# service_setting
# General Practice             359274
# Primary Care Network         183790
# Other                        138789
# Extended Access Provision    108122
# Unmapped                      27419
# Name: count, dtype: int64

# %%
# Determine the number of context types.
num_context = nc['context_type'].nunique()

# List of context types
context_type = nc['context_type'].value_counts()

print('Number of context types:', num_context)
print('Context types and counts:')
print(context_type)
# Out:
# Number of context types: 3
# Context types and counts:
# context_type
# Care Related Encounter    700481
# Inconsistent Mapping       89494
# Unmapped                   27419
# Name: count, dtype: int64

# %%
# Determine the number of national categories.
num_categories = nc['national_category'].nunique()

# List of national categories
national_category =nc['national_category'].value_counts()

print('Number of national categories:', num_categories)
print('National categories and counts:')
print(national_category)
# Out:
# Number of national categories: 18
# National categories and counts:
# national_category
# Inconsistent Mapping                                                   89494
# General Consultation Routine                                           89329
# General Consultation Acute                                             84874
# Planned Clinics                                                        76429
# Clinical Triage                                                        74539
# Planned Clinical Procedure                                             59631
# Structured Medication Review                                           44467
# Service provided by organisation external to the practice              43095
# Home Visit                                                             41850
# Unplanned Clinical Activity                                            40415
# Patient contact during Care Home Round                                 28795
# ...

# %%
# Determine the number of appointment statuses.
num_appointment_status = ar['appointment_status'].nunique()

# List of appointment status
appointment_status = ar['appointment_status'].value_counts()

print('Number of appointment status:', num_appointment_status)
print('Appointment status and counts:')
print(appointment_status)
# Out:
# Number of appointment status: 3
# Appointment status and counts:
# appointment_status
# Attended    232137
# Unknown     201324
# DNA         163360
# Name: count, dtype: int64

# %% [markdown]
# ### Supplementary questions

# %% [markdown]
# Determine number of apointments
# Since the count_of_appointments column in the national categories dataset is
# already counted and it is integer datatype, the sum() function must be used
# to determine the total appointments instead of count() function.

# %%
# Determine number of appointments
total_appointments = nc['count_of_appointments'].sum()

print('Total number of appointments:', total_appointments)
# Out:
# Total number of appointments: 296046770

# %%
# Determine number of appointment modes
"""This calculates the number of unique appointment modes within the network"""
num_appointment_mode = ar['appointment_mode'].nunique()
print('Number of appointment modes:', num_appointment_mode)
# Out:
# Number of appointment modes: 5

# %%
# Determine the distribution of appointments mode
"""This shows the frequency of each appoiintment mode within the dataset"""
appointment_mode_count = ar['appointment_mode'].value_counts()

print('Appointment mode distribution:')
print(appointment_mode_count)
# Out:
# Appointment mode distribution:
# appointment_mode
# Face-to-Face    180410
# Telephone       166483
# Home Visit      111194
# Unknown          79147
# Video/Online     59587
# Name: count, dtype: int64

# %% [markdown]
# > ***Check*** that you have adequately satisfied the expectations of the current module and that you have added code comments as well as Markdown cells documenting your analytic journey and observations to satisfy the assessment criteria.

# %% [markdown]
# #

# %% [markdown]
# ## 3) Assignment activity 3
# Continue your exploratory data analysis by answering the specific questions posed by the NHS as well as additional trends identified during data exploration. You can start by looking at the date range and the change in behaviour over time for the available data sources.

# %% [markdown]
# ### Continue to explore the data and search for answers to more specific questions posed by the NHS.

# %% [markdown]
# **Question 1:** Between what dates were appointments scheduled?

# %%
# View the first five rows of appointment_date for the ad DataFrame to determine the date format.
"""This is to display the first 5 rows of the 'appointment_date' column to inspect the 
date format"""

print('First 5 rows of appointment_date column of the ad Dataframe:')
print(ad['appointment_date'].head())
# Out:
# First 5 rows of appointment_date column of the ad Dataframe:
# 0    01-Dec-21
# 1    01-Dec-21
# 2    01-Dec-21
# 3    01-Dec-21
# 4    01-Dec-21
# Name: appointment_date, dtype: object

# %%
# View the first five rows of appointment_date for the nc DataFrame to determine the date format.
"""This is to display the first 5 rows of the National Category data
appointment_date column to inspect the date format"""

print('First 5 rows of apppointment_date column of the nc DataFrame:')
print(nc['appointment_date'].head())
# Out:
# First 5 rows of apppointment_date column of the nc DataFrame:
# 0   2021-08-02
# 1   2021-08-02
# 2   2021-08-02
# 3   2021-08-02
# 4   2021-08-02
# Name: appointment_date, dtype: datetime64[ns]

# %%
# Change the date format of ad['appointment_date'].
"""This is to convert the 'appointment_date' column of the ad DataFrame from object
(string) to datetime format. The UK datatime format used since NHS is UK based"""

ad['appointment_date'] = pd.to_datetime(ad['appointment_date'], dayfirst=True)

# View the DataFrame.
ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0       2021-12-01           31-60 Minutes                    364
# 1       2021-12-01           21-30 Minutes                    619
# ...

# %%
# View updated first 5 rows of the appointment_date column

"""This is to display the first 5 rows of the 'appointment_date' column to inspect the 
date format after of data type"""

print('First 5 rows of appointment_date column of the ad Dataframe after conversion to datetime format:')
print(ad['appointment_date'].head())
# Out:
# First 5 rows of appointment_date column of the ad Dataframe after conversion to datetime format:
# 0   2021-12-01
# 1   2021-12-01
# 2   2021-12-01
# 3   2021-12-01
# 4   2021-12-01
# Name: appointment_date, dtype: datetime64[ns]

# %%
# Change the format of ar['appointment_date'] to datetime.
"""This is to convert the 'appointment_month' column of the ar DataFrame from object
(string) to datetime format."""

ar['appointment_month'] = pd.to_datetime(ar['appointment_month'])


# View the DataFrame.
ar.head()
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 1    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 2    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 3    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 4    E54000034        2020-01-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
# Determine the minimum and maximum dates in the ad DataFrame.
# Use appropriate docstrings.
"""This displays the earliest and the latest dates in the appointment_date 
column of the ad DataFrame"""

min_date = ad['appointment_date'].min()
max_date = ad['appointment_date'].max()

print('Earliest appointment date:', min_date)
print('Latest appointment date:', max_date)
# Out:
# Earliest appointment date: 2021-12-01 00:00:00
# Latest appointment date: 2022-06-30 00:00:00

# %%
# Determine the minimum and maximum dates in the nc DataFrame.
# Use appropriate docstrings.
"""This displays the earliest and the latest dates in the appointment_date 
column of the nc DataFrame"""

min_date = nc['appointment_date'].min()
max_date = nc['appointment_date'].max()

print('Earliest appointment date:', min_date)
print('Latest appointment date:', max_date)
# Out:
# Earliest appointment date: 2021-08-01 00:00:00
# Latest appointment date: 2022-06-30 00:00:00

# %% [markdown]
# **Question 2:** Which service setting was the most popular for NHS North West London from 1 January to 1 June 2022?

# %%
# For each of these service settings, determine the number of records available for the period and the location. 
"""This is to create a subset of the nc Dataframe for NHS North West London ICB -W2U3Z
between the period of 01 January 2022 to 01 June 2022 and deermine the number of service settings"""

nhs_north_west_london_name = ['NHS North West London ICB - W2U3Z']
# Filter by location
nc_subset = nc[nc['sub_icb_location_name'].isin(nhs_north_west_london_name)]

#Filter by date range
nc_subset = nc_subset[
            (nc_subset['appointment_date'] >= '2022-01-01') &
            (nc_subset['appointment_date'] <= '2022-06-01')]

# Number of Service settings
num_service_settings = nc_subset['service_setting'].nunique()

# View the output.
print('Number of service settings:', num_service_settings)

# frequency of each settings
print('Number of service setings recorded at NHS North West London ICB - W2U3Z:', nc_subset['service_setting'].value_counts())
# Out:
# Number of service settings: 5
# Number of service setings recorded at NHS North West London ICB - W2U3Z: service_setting
# General Practice             2104
# Other                        1318
# Primary Care Network         1272
# Extended Access Provision    1090
# Unmapped                      152
# Name: count, dtype: int64

# %%
# View the subset Dataframe of NHS North West London ICB - W2U3Z
nc_subset
# Out:
#        appointment_date icb_ons_code              sub_icb_location_name  \
# 800289       2022-01-01    E54000027  NHS North West London ICB - W2U3Z
# 800290       2022-01-01    E54000027  NHS North West London ICB - W2U3Z
# 800291       2022-01-01    E54000027  NHS North West London ICB - W2U3Z
# 800292       2022-01-01    E54000027  NHS North West London ICB - W2U3Z
# 800293       2022-01-01    E54000027  NHS North West London ICB - W2U3Z
# ...                 ...          ...                                ...
# 806220       2022-06-01    E54000027  NHS North West London ICB - W2U3Z
# 806221       2022-06-01    E54000027  NHS North West London ICB - W2U3Z
# 806222       2022-06-01    E54000027  NHS North West London ICB - W2U3Z
# 806223       2022-06-01    E54000027  NHS North West London ICB - W2U3Z
# 806224       2022-06-01    E54000027  NHS North West London ICB - W2U3Z
#
#                   service_setting            context_type  \
# ...

# %% [markdown]
# **Question 3:** Which month had the highest number of appointments?

# %%
# Number of appointments per month == sum of count_of_appointments by month.
# Use the groupby() and sort_values() functions.
"""This relates to London NorthWest ICB Location"""

monthly_counts = nc_subset.groupby(
    nc_subset['appointment_date'].dt.to_period('M')
).size()

# Sort in descending order
monthly_counts_sorted = monthly_counts.sort_values(ascending=False)

# Get highest month
highest_month = monthly_counts_sorted.index[0]
highest_counts = monthly_counts_sorted.iloc[0]

print('Month with highest appointments:', highest_month)
print('Number of appointments:', highest_counts)
# Out:
# Month with highest appointments: 2022-03
# Number of appointments: 1271

# %%
monthly_totals = nc.groupby(
    nc['appointment_date'].dt.to_period('M')
)['count_of_appointments'].sum()

# Sort in descending order
monthly_totals_sorted = monthly_counts.sort_values(ascending=False)

# Get highest month
highest_month = monthly_totals_sorted.index[0]
highest_total = monthly_totals_sorted.iloc[0]

print('Month with highest appointments:', highest_month)
print('Number of appointments:', highest_counts)
# Out:
# Month with highest appointments: 3
# Number of appointments: 1271

# %%
# Duplicate with the above, check and delete

# %% [markdown]
# **Question 4:** What was the total number of records per month?

# %%
# Total number of records per month.
"""This shows the total number of appointment records per month in the nc_subset DataFrame"""

# Group by Year-Month and count records
records_per_month = nc_subset.groupby(
    nc_subset['appointment_date'].dt.to_period('M')).size()

# Sort according to month of year
records_per_month = records_per_month.sort_index()

print('Total number of records per month in the nc subset of North West London ICB - W2U3Z for the period Jan-Jun 2022:')
print(records_per_month)
# Out:
# Total number of records per month in the nc subset of North West London ICB - W2U3Z for the period Jan-Jun 2022:
# appointment_date
# 2022-01    1183
# 2022-02    1113
# 2022-03    1271
# 2022-04    1121
# 2022-05    1201
# 2022-06      47
# Freq: M, dtype: int64

# %%
# Group by Year-Month and count records
records_per_month = nc.groupby(
    nc['appointment_date'].dt.to_period('M')).size()

# Sort according to month of year
records_per_month = records_per_month.sort_index()

print('Total number of appointments records per month in the nc dataset:')
print(records_per_month)
# Out:
# Total number of appointments records per month in the nc dataset:
# appointment_date
# 2021-08    69999
# 2021-09    74922
# 2021-10    74078
# 2021-11    77652
# 2021-12    72651
# 2022-01    71896
# 2022-02    71769
# 2022-03    82822
# 2022-04    70012
# 2022-05    77425
# 2022-06    74168
# Freq: M, dtype: int64

# %%
# Group by Year-Month and count records
records_per_month = ad.groupby(
    ad['appointment_date'].dt.to_period('M')).size()

# Sort according to month of year
records_per_month = records_per_month.sort_index()

print('Total number of appointments records per month in the ad dataset:')
print(records_per_month)
# Out:
# Total number of appointments records per month in the ad dataset:
# appointment_date
# 2021-12    19507
# 2022-01    19643
# 2022-02    18974
# 2022-03    21236
# 2022-04    19078
# 2022-05    20128
# 2022-06    19227
# Freq: M, dtype: int64

# %% [markdown]
# These figures of total number of appointments are counts (number of rows) and not sum of totals.

# %% [markdown]
# > ***Check*** that you have adequately satisfied the expectations of the current module and that you have added code comments as well as Markdown cells documenting your analytic journey and observations to satisfy the assessment criteria.

# %% [markdown]
# #

# %% [markdown]
# ## 4) Assignment activity 4
# Use visual techniques to explore and communicate patterns in the data. Note that you will likely revisit this section when preparing the final visualisations to be used in your technical report and business presentation. Make sure to document your thoughts and observations as they relate to various potential stakeholders.
#
# The seasons are summer (June to August 2021), autumn (September to November 2021), winter (December to February 2022), and spring (March to May 2022).

# %% [markdown]
# ### Create visualisations and identify possible monthly and seasonal trends in the data.

# %%
# Import the necessary libraries.
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# %% [markdown]
# ### Objective 1
# Create three visualisations indicating the number of appointments per month for service settings, context types, and national categories.

# %%
# Change the data type of the appointment month to string to allow for easier plotting.
"""Convert the appointment month column to stringformat to allow easier plotting."""

# Convert to string
nc['appointment_month'] = nc['appointment_month'].astype(str)

# Show result
print(nc.head())
print('\nDate type:', nc['appointment_month'].dtype)
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Aggregate on a monthly level and determine the sum of records per month.
"""Aggregate the nc DataFrame on a monthly level and calculate the sum of appointment 
records per month"""

# Group by Year-Month and sum appointments
monthly_sum = nc.groupby(
    nc['appointment_date'].dt.to_period('M'))['count_of_appointments'].sum()
# Sort by month
monthly_sum = monthly_sum.sort_index()

# View the output.
print('Total number of appointments per month:')
print(monthly_sum)
# Out:
# Total number of appointments per month:
# appointment_date
# 2021-08    23852171
# 2021-09    28522501
# 2021-10    30303834
# 2021-11    30405070
# 2021-12    25140776
# 2022-01    25635474
# 2022-02    25355260
# 2022-03    29595038
# 2022-04    23913060
# 2022-05    27495508
# 2022-06    25828078
# Freq: M, Name: count_of_appointments, dtype: int64

# %%
"""Aggregate appointments per month and service setting, and determine the sum of appointments per month"""

# Create new DataFrame
nc_ss = nc[['appointment_date', 'service_setting', 'count_of_appointments']].copy()

# Create monthly column
nc_ss['appointment_month'] = nc_ss['appointment_date'].dt.to_period('M')

# Group by month and service setting
nc_ss_monthly = nc_ss.groupby(
    ['appointment_month', 'service_setting'])['count_of_appointments'].sum().reset_index()

print('Appointments per month and service setting:')
print(nc_ss_monthly.head())

# Sum total of appointments per month
monthly_total = nc_ss.groupby('appointment_month')['count_of_appointments'].sum()

print('\nTotal appointments per month:')
print(monthly_total)
nc_ss
# Out:
# Appointments per month and service setting:
#   appointment_month            service_setting  count_of_appointments
# 0           2021-08  Extended Access Provision                 160927
# 1           2021-08           General Practice               21575852
# 2           2021-08                      Other                 449101
# 3           2021-08       Primary Care Network                 432448
# 4           2021-08                   Unmapped                1233843
#
# Total appointments per month:
# appointment_month
# 2021-08    23852171
# 2021-09    28522501
# 2021-10    30303834
# 2021-11    30405070
# 2021-12    25140776
# 2022-01    25635474
# 2022-02    25355260
# 2022-03    29595038
# 2022-04    23913060
# 2022-05    27495508
# 2022-06    25828078
# Freq: M, Name: count_of_appointments, dtype: int64
#        appointment_date            service_setting  count_of_appointments  \
# 0            2021-08-02       Primary Care Network                      3
# ...

# %% [markdown]
# **Service settings:**

# %%
# Plot the appointments over the available date range, and review the service settings for months.
# Create a lineplot.
# Set figure size
plt.figure(figsize = (15, 12), facecolor = 'white')

# Convert appointment_month from period to timestamp

# Create lineplot
sns.lineplot(
    data = nc_ss,
    x = 'appointment_month',
    y = 'count_of_appointments',
    hue = 'service_setting',
    errorbar = None)
# To improve readability
plt.title('Appointments Over Months by Service Settings')
plt.xlabel('Appointments Month')
plt.ylabel('Count of Appointments')
plt.xticks(rotation = 45)


plt.show()

# %% [markdown]
# **Context types:**

# %%
# Create a separate data set that can be used in future weeks. 
"""Aggregate appointments per month and service setting, and determine the sum of appointments per month"""

# Create new DataFrame
nc_ct = nc[['appointment_date', 'context_type', 'count_of_appointments']].copy()

# Create monthly column
nc_ct['appointment_month'] = nc_ct['appointment_date'].dt.to_period('M')

# Group by month and service setting
nc_ct_monthly = nc_ct.groupby(
    ['appointment_month', 'context_type'])['count_of_appointments'].sum().reset_index()

print('Appointments per month and contest type:')
print(nc_ct_monthly.head())

# Sum total of appointments per month
monthly_total = nc_ct.groupby('appointment_month')['count_of_appointments'].sum()

print('\nTotal appointments per month:')
print(monthly_total)

# View the output.
nc_ct
print(nc_ct.dtypes)
# Out:
# Appointments per month and contest type:
#   appointment_month            context_type  count_of_appointments
# 0           2021-08  Care Related Encounter               20255235
# 1           2021-08    Inconsistent Mapping                2363093
# 2           2021-08                Unmapped                1233843
# 3           2021-09  Care Related Encounter               24404251
# 4           2021-09    Inconsistent Mapping                2782135
#
# Total appointments per month:
# appointment_month
# 2021-08    23852171
# 2021-09    28522501
# 2021-10    30303834
# 2021-11    30405070
# 2021-12    25140776
# 2022-01    25635474
# 2022-02    25355260
# 2022-03    29595038
# 2022-04    23913060
# 2022-05    27495508
# 2022-06    25828078
# Freq: M, Name: count_of_appointments, dtype: int64
# appointment_date         datetime64[ns]
# context_type                     object
# count_of_appointments             int64
# appointment_month             period[M]
# dtype: object

# %%
# Plot the appointments over the available date range, and review the context types for months.
# Create a lineplot.

# Set figure size
plt.figure(figsize = (15, 12), facecolor = 'white')

# Create lineplot
sns.lineplot(
    data = nc_ct,
    x = 'appointment_month',
    y = 'count_of_appointments',
    hue = 'context_type',
    errorbar = None)
# To improve readability
plt.title('Appointments Over Months by Context Types')
plt.xlabel('Appointments Month')
plt.ylabel('Count of Appointments')
plt.xticks(rotation = 45)

plt.savefig('my_chart.png', dpi = 300, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# **National categories:**

# %%
# Create a separate data set that can be used in future weeks. 
"""Aggregate appointments per month and national_category, and determine the sum of appointments per month"""

# Create new DataFrame
nc_nc = nc[['appointment_date', 'national_category', 'count_of_appointments']].copy()

# Create monthly column
nc_nc['appointment_month'] = nc_nc['appointment_date'].dt.to_period('M')

# Group by month and service setting
nc_nc_monthly = nc_nc.groupby(
    ['appointment_month', 'national_category'])['count_of_appointments'].sum().reset_index()

print('Appointments per month and contest type:')
print(nc_nc_monthly.head())

# Sum total of appointments per month
monthly_total = nc_nc.groupby('appointment_month')['count_of_appointments'].sum

print('\nTotal appointments per month:')
print(monthly_total)

# View the output.
nc_nc
# Out:
# Appointments per month and contest type:
#   appointment_month  \
# 0           2021-08
# 1           2021-08
# 2           2021-08
# 3           2021-08
# 4           2021-08
#
#                                                      national_category  \
# 0  Care Home Needs Assessment & Personalised Care and Support Planning
# 1                                                      Care Home Visit
# 2                                                      Clinical Triage
# 3                                           General Consultation Acute
# 4                                         General Consultation Routine
#
#    count_of_appointments
# 0                  29676
# 1                  47583
# 2                3704207
# 3                4280920
# 4                7756045
#
# Total appointments per month:
# <bound method GroupBy.sum of <pandas.core.groupby.generic.SeriesGroupBy object at 0x358d50710>>
#        appointment_date                       national_category  \
# ...

# %%
# Plot the appointments over the available date range, and review the national categories for months.
# Create a lineplot.
# Set figure size
plt.figure(figsize = (15, 12), facecolor = 'white')


# Convert appointment_month to datetime


# Create lineplot
sns.lineplot(
    data = nc_nc,
    x = 'appointment_month',
    y = 'count_of_appointments',
    hue = 'national_category',
    errorbar = None)
# To improve readability
plt.title('Appointments Over Months by National Category')
plt.xlabel('Appointments Month')
plt.ylabel('Count of Appointments')
plt.xticks(rotation = 45)
plt.savefig('my_chart.png', dpi = 300, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ### Objective 2
# Create four visualisations indicating the number of appointments for service setting per season.

# %% [markdown]
# **Summer:**

# %%
# Create a separate data set that can be used in future weeks. 
# Convert to datetime
nc['appointment_date'] = pd.to_datetime(nc['appointment_date'])

# Monthly agrregation
nc['month'] = nc['appointment_date'].dt.to_period('M').astype(str)

# Aggregate appoitments per month and service setting
# Create required new DataFrame
nc_ss_day = (nc.groupby(['appointment_month', 'service_setting'])['count_of_appointments']
            .sum().reset_index())

# View the output
nc_ss_day.head()
# Out:
#   appointment_month            service_setting  count_of_appointments
# 0           2021-08  Extended Access Provision                 160927
# 1           2021-08           General Practice               21575852
# 2           2021-08                      Other                 449101
# 3           2021-08       Primary Care Network                 432448
# 4           2021-08                   Unmapped                1233843

# %%
# Visualise the subset using a lineplot.
def plot_season(data, months, title):
    season_df = data[data['appointment_month'].isin(months)]

    # Sort months so lines appear properly
    season_df = season_df.sort_values('appointment_month')

    plt.figure(figsize = (15, 12))
    sns.lineplot(
        data = season_df,
        x = 'appointment_month',
        y = 'count_of_appointments',
        hue = 'service_setting',
        errorbar = None)
        

    plt.title(title)
    plt.xlabel('Month')
    plt.ylabel('Number of Appointments')
    plt.xticks(rotation = 45)
    plt.tight_layout()
    plt.show()


summer_months = ['2021-06', '2021-07', '2021-08']
plot_season(nc_ss_day, summer_months, 'Summer 2021')

# %% [markdown]
# **Autumn:**

# %%
# Create a separate data set that can be used in future weeks. 
# Convert date column to datetime
nc_ss_day = nc.copy()

nc_ss_day['appointment_date'] = pd.to_datetime(nc_ss_day['appointment_date'])

# Aggregate to monthly appointments using groupby()
nc_ss_month = (nc_ss_day.groupby(
    [pd.Grouper(key = 'appointment_date', freq ='M'),
    'service_setting'])
               ['count_of_appointments'].sum().reset_index())

# Create season labels
def get_season(date):
    y = date.year
    m = date.month
    if y == 2021 and m in [6, 7, 8]:
        return 'Summer 2021'
    elif y == 2021 and m in [9, 10, 11]:
        return 'Autumn 2021'
    elif (y == 2021 and m == 12) or (y == 2022 and m in [1, 2]):
        return 'Winter 2022'
    elif y == 2022 and m in [3, 4, 5]:
        return 'Spring 2022'
    else:
        return 'Other'

# View the output.
nc_ss_month['season'] = nc_ss_month['appointment_date'].apply(get_season)

season_totals = nc_ss_month.groupby('season')['count_of_appointments'].sum().reset_index()

season_totals
print(nc_ss_month['appointment_date'].min())
print(nc_ss_month['appointment_date'].max())
# View the output.
# Out:
#         season  count_of_appointments
# 0  Autumn 2021               89231405
# 1        Other               25828078
# 2  Spring 2022               81003606
# 3  Summer 2021               23852171
# 4  Winter 2022               76131510

# %%
# Visualise the subset using a lineplot.
def plot_season(data, months, title):
    season_df = data[data['appointment_month'].isin(months)]

    # Sort months so lines appear properly
    season_df = season_df.sort_values('appointment_month')

    plt.figure(figsize = (15, 12))
    sns.lineplot(
        data = season_df,
        x = 'appointment_month',
        y = 'count_of_appointments',
        hue = 'service_setting',
        errorbar = None)
        

    plt.title(title)
    plt.xlabel('Month')
    plt.ylabel('Number of Appointments')
    plt.xticks(rotation = 45)
    plt.tight_layout()
    
    plt.savefig('my_chart.png', dpi = 300, bbox_inches = 'tight')
    plt.show()
autumn_months = ['2021-09', '2021-10', '2021-11']
plot_season(nc_ss_day, autumn_months, 'Autumn 2021')

# %% [markdown]
# **Winter:**

# %%
# Create a separate data set that can be used in future weeks. 
# Convert to datetime
nc['appointment_date'] = pd.to_datetime(nc['appointment_date'])

# Monthly agrregation
nc['month'] = nc['appointment_date'].dt.to_period('M').astype(str)

# Aggregate appoitments per month and service setting
# Create required new DataFrame
nc_ss_day = (nc.groupby(['appointment_month', 'service_setting'])['count_of_appointments']
            .sum().reset_index())

nc_ss_day.head()


# create a function to plot seasons
# This code snippet avoids repetition


# View the output.
nc_ss_day.head()
# Out:
#   appointment_month            service_setting  count_of_appointments
# 0           2021-08  Extended Access Provision                 160927
# 1           2021-08           General Practice               21575852
# 2           2021-08                      Other                 449101
# 3           2021-08       Primary Care Network                 432448
# 4           2021-08                   Unmapped                1233843

# %%
# Visualise the subset using a lineplot.


# This code snippet avoids repetition
def plot_season(data, months, title):
    season_df = data[data['appointment_month'].isin(months)]

    # Sort months so lines appear properly
    season_df = season_df.sort_values('appointment_month')

    plt.figure(figsize = (15, 12))
    sns.lineplot(
        data = season_df,
        x = 'appointment_month',
        y = 'count_of_appointments',
        hue = 'service_setting',
        errorbar = None)
        

    plt.title(title)
    plt.xlabel('Month')
    plt.ylabel('Number of Appointments')
    plt.xticks(rotation = 45)
    plt.tight_layout()
    plt.savefig('my_chart.png', dpi = 300, bbox_inches = 'tight')
    plt.show()
    
# Show output plot for winter
winter_months = ['2021-12', '2022-01', '2022-02']
plot_season(nc_ss_day, winter_months, 'Winter 2021-2022')

# %% [markdown]
# **Spring:**

# %%
# Create a separate data set that can be used in future weeks. 
def get_season(date):
    if pd.Timestamp('2021-08-01') <= date <= pd.Timestamp('2021-08-31'):
        return 'Summer 2021'
    elif pd.Timestamp('2021-09-01') <= date <= pd.Timestamp('2021-11-30'):
        return 'Autumn 2021'
    elif pd.Timestamp('2021-12-01') <= date <= pd.Timestamp('2022-02-28'):
        return 'Winter 2021/22'
    elif pd.Timestamp('2022-03-01') <= date <= pd.Timestamp('2022-05-31'):
        return 'Spring 2022'
    else:
        return 'Other'

nc_ss_month['season'] = nc_ss_month['appointment_date'].apply(get_season)

nc_ss_month.groupby('season')['appointment_date'].nunique()

# View the output.
# Out:
# season
# Autumn 2021       3
# Other             1
# Spring 2022       3
# Summer 2021       1
# Winter 2021/22    3
# Name: appointment_date, dtype: int64

# %%
# Visualise the subset using a lineplot.
def plot_season(data, months, title):
    season_df = data[data['appointment_month'].isin(months)]

    # Sort months so lines appear properly
    season_df = season_df.sort_values('appointment_month')

    plt.figure(figsize = (15, 12))
    sns.lineplot(
        data = season_df,
        x = 'appointment_month',
        y = 'count_of_appointments',
        hue = 'service_setting',
        errorbar = None)
        

    plt.title(title)
    plt.xlabel('Month')
    plt.ylabel('Number of Appointments')
    plt.xticks(rotation = 45)
    plt.tight_layout()
    plt.savefig('my_chart.png', dpi = 300, bbox_inches = 'tight')
    plt.show()
    

spring_months = ['2022-03', '2022-04', '2022-05']
plot_season(nc_ss_day, spring_months, 'Spring 2021-2022')

# %% [markdown]
# > ***Check*** that you have adequately satisfied the expectations of the current module and that you have added code comments as well as Markdown cells documenting your analytic journey and observations to satisfy the assessment criteria.

# %% [markdown]
# #

# %% [markdown]
# ## 5) Assignment activity 5

# %% [markdown]
# ### Analyse tweets from Twitter with hashtags related to healthcare in the UK.

# %%
# Libraries and settings needed for analysis.
import pandas as pd
import seaborn as sns

# Set the figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# Maximum column width to display.
pd.options.display.max_colwidth = 200

# %%
# Load the data set.
tweets = pd.read_csv('tweets.csv')

# View the DataFrame.
tweets.head()
# Out:
#               tweet_id  \
# 0  1567629223795527681
# 1  1567582846612553728
# 2  1567582787070304256
# 3  1567582767625428992
# 4  1567582720460570625
#
#                                                                                                                                                                                            tweet_full_text  \
# 0  As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                              RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                           RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…
# ...

# %%
# Explore the metadata and data set.
tweets.info
# Out:
# <bound method DataFrame.info of                  tweet_id  \
# 0     1567629223795527681
# 1     1567582846612553728
# 2     1567582787070304256
# 3     1567582767625428992
# 4     1567582720460570625
# ...                   ...
# 1169  1567583004209332227
# 1170  1567582945342267393
# 1171  1567582936014241792
# 1172  1567582892892782592
# 1173  1567582846847533058
#
#                                                                                                                                                                                               tweet_full_text  \
# 0     As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                                 RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# ...

# %%
tweets.describe()
# Out:
#            tweet_id  tweet_retweet_count  tweet_favorite_count
# count  1.174000e+03          1174.000000            1174.00000
# mean   1.567612e+18             8.629472               0.37138
# std    2.427553e+13            29.784675               2.04470
# min    1.567574e+18             0.000000               0.00000
# 25%    1.567590e+18             0.000000               0.00000
# 50%    1.567611e+18             1.000000               0.00000
# 75%    1.567633e+18             3.000000               0.00000
# max    1.567655e+18           303.000000              42.00000

# %% [markdown]
# Would it be useful to only look at retweet and favourite tweet messages?
# **The Answer is Yes**
#
# **Explain your answer**.
#
# The insights from analysing the retweets and favourite messages provide supporting evidence
# to identify the top trending healthcare-related hashtags about the NHS.
#
# These will assist in the measurement of how widely a hashtag spreads/popularity (i.e. retweets).
#
# These measures will also indicate how positively a tweet is received (i.e. likes/favourites rated).
#
# These measures also support the identification of trending hashtags. These refers to tags that
# users engage with or comments on.
#
# **Based on the statistics derived from the DataFrame 'tweets.describe()', indicate the following:**
#
# Mean = on average only 8 tweets were retweeted but almost none was liked (favourite ratings).
#
# Upper quartile 75% = This shows out of 75% of tweets, only 3 got retweeted, and zero was liked (favourite ratings).
#
# Max = This indicates that 3 or fewer tweets received 303 retweets with only 42 likes (favourite ratings).
#
# Standard Deviation = With very high measure of 29.78 with very low mean, shows high volatility in retweets.
#
# This indicate extreme outliers or data skewed to the right.

# %%
# Create a new DataFrame containing only the text.
# Derive tweets_text
tweets_text = tweets[['tweet_full_text']]

# View the DataFrame.
tweets_text.head()
# Out:
#                                                                                                                                                                                            tweet_full_text
# 0  As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                              RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                           RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…
# ...

# %%
# Loop through the messages, and create a list of values containing the # symbol.
tags = []

# Using loop provided to extract list of hashtags
for y in [x.split(' ') for x in tweets['tweet_full_text'].values]:
    for z in y:
        if '#' in z:
            # Change to lower case
            tags.append(z.lower())


tag_series = pd.Series(tags)
tag_counts = tag_series.value_counts()

# %%
# Display the first 30 records.
tag_counts.head(30)
# Out:
# #healthcare                    716
# #health                         80
# #medicine                       41
# #ai                             40
# #job                            38
# #medical                        35
# #strategy                       30
# #pharmaceutical                 28
# #digitalhealth                  25
# #pharma                         25
# #marketing                      25
# #medtwitter                     24
# #biotech                        24
# #competitiveintelligence        24
# #meded                          23
# #vaccine                        18
# #hiring                         18
# #news                           17
# #machinelearning                17
# #technology                     17
# #coronavirus                    16
# #womeninmedicine                16
# #covid                          16
# #competitivemarketing           16
# #wellness                       15
# #healthtech                     15
# #doctorofveterinarymedicine     14
# ...

# %%
# Convert the series to a DataFrame in preparation for visualisation.
tags_df = tag_counts.reset_index()

# Rename the columns.
# Choosing meaningful name
tags_df.columns = ['hashtag_name', 'count']

# %%
# Fix the count datatype.
"""The count column is currently int64, which is correct.
Pandas automatically assigns int64 for integer columns.
The count column shows the number of times each hashtag appears"""

# View the result.
tags_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1754 entries, 0 to 1753
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   hashtag_name  1754 non-null   object
#  1   count         1754 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 27.5+ KB

# %%
# Display records where the count is larger than 10.

# Using user-defined function
popular_tags = tags_df[tags_df['count'] > 10]
popular_tags
# Out:
#                    hashtag_name  count
# 0                   #healthcare    716
# 1                       #health     80
# 2                     #medicine     41
# 3                           #ai     40
# 4                          #job     38
# 5                      #medical     35
# 6                     #strategy     30
# 7               #pharmaceutical     28
# 8                #digitalhealth     25
# 9                       #pharma     25
# 10                   #marketing     25
# 11                  #medtwitter     24
# 12                     #biotech     24
# 13     #competitiveintelligence     24
# 14                       #meded     23
# 15                     #vaccine     18
# 16                      #hiring     18
# 17                        #news     17
# 18             #machinelearning     17
# 19                  #technology     17
# 20                 #coronavirus     16
# 21             #womeninmedicine     16
# 22                       #covid     16
# ...

# %%
# Create a Seaborn barplot displaying records with a count larger than 10.
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (15, 12))

sns.barplot(
    data = popular_tags,
    x = 'count',
    y = 'hashtag_name')

plt.title('Hashtags with Count greater than 10')
plt.xlabel('Count')
plt.ylabel('Hashtag_name')

plt.show()

# %%
# Create the plot.
# Remove over-represented hashtags and show most frequently used
""" From my observation of the visualisation of hashtags with count greater than 10, shows that #healthcare
is over-represented having over 700 counts. This could be considered an outlier and hence, so have decided 
to remove from the hashtag list."""

# Filter overrepresented hashtag
overrepresented_tags = ['#healthcare']
filtered_tags = tags_df[~tags_df['hashtag_name'].isin(overrepresented_tags)]

# Display most frequently used hashtag
filtered_tags = filtered_tags.sort_values(by='count',ascending= False).reset_index()

filtered_tags.head(10)

# View the barplot.
plt.figure(figsize = (15, 12))

sns.barplot(
    data = filtered_tags.head(10),
    x = 'count',
    y = 'hashtag_name')

plt.title('10 Most Frequently Used Hashtags')
plt.xlabel('Count')
plt.ylabel('Hashtag_name')
plt.savefig('my_chart.png', dpi = 300, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# **Summarise any insights you've discovered and anything you would like to explore further.**
#
# Major insights or conclusions discovered from this Tweeter module are as follows:
# * Most tweets get little or no enagegment. That is, these tweets are not commented on or liked.
# * Few tweets go viral such as #healthcare. This shows how the public is interested in health matters.
# * Averages are misleading as there are extreme outliers, thereby affecting the accuracy of the mean value
# * In this dataset, the median is more accurate
#
# **Anything to explore further**
#
# * 1 It will be more illuminationg to visualise the tweets in boxplots, rather than barplots. Due to the presence of extreme values, boxplots will improve the visualisations.
# * 2 How to accurately visualise the most relevant tweets to the NHS

# %% [markdown]
# **How Trending hastags Can Be Used In Decision Making**
#
# By determining trending hashtags, NHS decision makers
# * will know what topics the public is actively discussing
# * which campaigns/awareness are gaining attention (this will inform aditional funding or otherwise)
# * where hashtag has high freqency but low engagement, this will inform message effectiveness or lack thereof.
#
# **Summary**
#
# Trending healthcare hashtags provide policy makers with real-time population-level concerns,
# campaign effectivesness, and service pressure.

# %% [markdown]
#  > ***Check*** that you have adequately satisfied the expectations of the current module and that you have added code comments as well as Markdown cells documenting your analytic journey and observations to satisfy the assessment criteria.

# %% [markdown]
# #

# %% [markdown]
# ## 6) Assignment activity 6
# In the final module you will answer additional questions from the NHS as well as additional questions and observations you identified. Make sure to revisit previous sections that may provide useful insights to the questions posed in Module 6 where required.

# %% [markdown]
# ### Investigate the main concerns posed by the NHS.

# %%
# Prepare your workstation.
# Load the appointments_regional.csv file.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ar_df = pd.read_csv('appointments_regional.csv')

# View the DataFrame.
ar_df.head()
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
# Print the min and max dates.
# Use appropriate docstrings.
"""This displays the earliest and the latest dates in the appointment_month 
column of the nc DataFrame"""

min_date = ar_df['appointment_month'].min()
max_date = ar_df['appointment_month'].max()

print('Earliest appointment month:', min_date)
print('Latest appointment month:', max_date)
# Out:
# Earliest appointment month: 2020-01
# Latest appointment month: 2022-06

# %%
# Filter the data set to only look at data from 2021-08 onwards.

ar_df = pd.read_csv('appointments_regional.csv')

# Apointment_month is currently object datatype
# Conver to datetime
ar_df['appointment_month'] = pd.to_datetime(ar_df['appointment_month'])

# Filter from 2021-08 onwards                                            
filtered_month = ar_df[ar_df['appointment_month'] >= '2021-08']

# View output
filtered_month
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 3652      E54000034        2021-08-01           Attended       GP
# 3653      E54000034        2021-08-01           Attended       GP
# 3654      E54000034        2021-08-01           Attended       GP
# 3655      E54000034        2021-08-01           Attended       GP
# 3656      E54000034        2021-08-01           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050        2022-06-01            Unknown  Unknown
# 596817    E54000050        2022-06-01            Unknown  Unknown
# 596818    E54000050        2022-06-01            Unknown  Unknown
# 596819    E54000050        2022-06-01            Unknown  Unknown
# 596820    E54000050        2022-06-01            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 3652       Face-to-Face                             1 Day
# ...

# %% [markdown]
# **Question 1:** Should the NHS start looking at increasing staff levels?

# %%
# Create an aggregated data set to review the different features.

# Create a new DataFrame with with required columns using the previous df = filtered_month
ar_agg = filtered_month[['appointment_month',
                'hcp_type',
                'appointment_status',
                'appointment_mode',
                'time_between_book_and_appointment',
                'count_of_appointments']].copy()

# View the DataFrame.
ar_agg
# Out:
#        appointment_month hcp_type appointment_status appointment_mode  \
# 3652          2021-08-01       GP           Attended     Face-to-Face
# 3653          2021-08-01       GP           Attended     Face-to-Face
# 3654          2021-08-01       GP           Attended     Face-to-Face
# 3655          2021-08-01       GP           Attended     Face-to-Face
# 3656          2021-08-01       GP           Attended     Face-to-Face
# ...                  ...      ...                ...              ...
# 596816        2022-06-01  Unknown            Unknown          Unknown
# 596817        2022-06-01  Unknown            Unknown          Unknown
# 596818        2022-06-01  Unknown            Unknown          Unknown
# 596819        2022-06-01  Unknown            Unknown          Unknown
# 596820        2022-06-01  Unknown            Unknown          Unknown
#
#        time_between_book_and_appointment  count_of_appointments
# ...

# %%
# Determine the total number of appointments per month.

# Create Monthly summary dataframe
ar_monthly = filtered_month[['appointment_month', 'count_of_appointments']].copy()

# Group by month
ar_monthly = filtered_month.groupby('appointment_month')['count_of_appointments'].sum().reset_index()

# Add a new column to indicate the average utilisation of services.
# Monthly aggregate / 30 to get to a daily value.
ar_monthly['daily_utilisation'] = (ar_monthly['count_of_appointments'] / 30)

# Reducing decimal places to one (1)
ar_monthly['daily_utilisation'] = ar_monthly['daily_utilisation'].round(1)

# To compare to the NHS planning capacity: Create a capacity percentage column
ar_monthly['capacity_%'] = (ar_monthly['daily_utilisation'] / MAX_CAPACITY * 100)

# Round capacity utilisation to 1 decimal place
ar_monthly['daily_utilisation'] = ar_monthly['daily_utilisation'].round(1)
ar_monthly['capacity_%'] = ar_monthly['capacity_%'].round(1)


# View the DataFrame.
ar_monthly.head()
# Out:
#   appointment_month  count_of_appointments  daily_utilisation  capacity_%
# 0        2021-08-01               23852171           795072.4        66.3
# 1        2021-09-01               28522501           950750.0        79.2
# 2        2021-10-01               30303834          1010127.8        84.2
# 3        2021-11-01               30405070          1013502.3        84.5
# 4        2021-12-01               25140776           838025.9        69.8

# %%
# Plot sum of count of monthly visits.

# Convert the appointment_month to string data type for ease of visualisation.
ar_monthly['appointment_month'] = ar_monthly['appointment_month'].astype(str)

# Create a lineplot with Seaborn.
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure()
sns.lineplot(data = ar_monthly,
             x = 'appointment_month',
             y = 'count_of_appointments')

plt.xticks(rotation = 45)
plt.title('Monthly Appointments/Visits')

plt.show()

# %%
# Plot monthly capacity utilisation.

# Round capacity utilisation to 1 decimal place
ar_monthly['daily_utilisation'] = ar_monthly['daily_utilisation'].round(1)
ar_monthly['capacity_%'] = ar_monthly['capacity_%'].round(1)

ar_monthly.head()


# Create a lineplot.
plt.figure()
sns.lineplot(data = ar_monthly,
             x = 'appointment_month',
             y = 'daily_utilisation')
plt.xticks(rotation = 45)
plt.title('Monthly Capacity Utilisation (Dailly Average)')

plt.show()

# %%
ar_monthly.tail()
# Out:
#    appointment_month  count_of_appointments  daily_utilisation  capacity_%
# 6         2022-02-01               25355260           845175.3        70.4
# 7         2022-03-01               29595038           986501.3        82.2
# 8         2022-04-01               23913060           797102.0        66.4
# 9         2022-05-01               27495508           916516.9        76.4
# 10        2022-06-01               25828078           860935.9        71.7

# %%
MAX_CAPACITY = 1_200_000

# To compare to the NHS planning capacity: Create a capacity percentage column
ar_monthly['capacity_%'] = (ar_monthly['daily_utilisation'] / MAX_CAPACITY * 100)

# Round capacity utilisation to 1 ddecimal place
ar_monthly['daily_utilisation'] = ar_monthly['daily_utilisation'].round(1)
ar_monthly['capacity_%'] = ar_monthly['capacity_%'].round(1)

ar_monthly.head()
# Out:
#   appointment_month  count_of_appointments  daily_utilisation  capacity_%
# 0        2021-08-01               23852171           795072.4        66.3
# 1        2021-09-01               28522501           950750.0        79.2
# 2        2021-10-01               30303834          1010127.8        84.2
# 3        2021-11-01               30405070          1013502.3        84.5
# 4        2021-12-01               25140776           838025.9        69.8

# %%
"""After using the prescribed (monthly appointments divided by 30),
daily activity levels were found to remain consistently high,
typically between 800,000 and 1 million appointments per day.
This represents approximately 70 -85% of the NHS guideline capacity.
This also shows that, the system operated close to capacity most of the time.
The analysis of monthly appointment data indicates that the NHS primary care services
operated at a consistently high level of activity throughout the study period.
Extimated dailyutilisation frequently approached the guideline capacity of 1.2 million
appointments per day. This suggests sustained system pressure.
Seasonal declines were observed during major holiday periods, particularly in December and April.
This may reflect reduced service availability rather than decreased healthcare need.
The data therefore highlights the resilience of service provision and persistent 
demand placed on the NHS services, paricularly General Practice among the service settings.

# %%
# Should the NHS increase its staff?
# The data suggests sustained pressure on services, but it is not enough on its own to 
# conclude that the NHS should start looking at increasing its staffing levels.
# Monthly appointments = 24 - 30 million
# Daily utilisation  = 800,000 - 1,000,000 per day
# NHS guideline maximum = 1,200,000 per day
# Capacity usage = 66 - 84%
# This shows the system is busy, but not cocsistently exceeding maximum capacity 
# and currently operating below the theoretical limit

# %% [markdown]
# **Question 2:** How do the healthcare professional types differ over time?

# %%
# Create a lineplot to answer the question.
# Convert month to datetime
hcp_trend['appointment_month'] = pd.to_datetime(hcp_trend['appointment_month'])

# Filter from August 2021 onwards
filtered_hcp = ar_df[ar_df['appointment_month'] >= '2021-08']

# Aggregate appointments by month and healthcare professional type (hcp_type) trends
hcp_trend = (
    filtered_hcp
    .groupby(['appointment_month', 'hcp_type'])['count_of_appointments'].sum().reset_index())

import seaborn as sns
import matplotlib.pyplot as plt

# Create the lineplot
plt.figure(figsize = (15, 12))
sns.lineplot(
    data = hcp_trend,
    x = 'appointment_month',
    y = 'count_of_appointments',
    hue = 'hcp_type')

plt.title('Appointment of Healthcare Professional Type Over Time')
plt.xlabel('Month')
plt.ylabel('Number of Appointments')
plt.xticks (rotation = 45)

plt.show()


"""from 2021-08 onwards, GP's consistently delivered the highest proportion of appointments. 
However, sustained contributions from other healthcare professionals (other practice staff)
demonstrate a multidisciplinary service model. 
Seasonal increases were observed across all professional groups except for during major 
holiday breaks such as christmas and easter as shown in the graph.
The unknown-group which flat-lined closer to zero. This could be the result of poor data collection"""
# Out:
# "from 2021-08 onwards, GP's consistently delivered the highest proportion of appointments. \nHowever, sustained contributions from other healthcare professionals (other practice staff)\ndemonstrate a multidisciplinary service model. \nSeasonal increases were observed across all professional groups except for during major \nholiday breaks such as christmas and easter as shown in the graph.\nThe unknown-group which flat-lined closer to zero. This could be the result of poor data collection"

# %% [markdown]
# **Question 3:** Are there significant changes in whether or not visits are attended?

# %%
# Create a lineplot to answer the question.

# Convert month to datetime
ar_df['appointment_month'] = pd.to_datetime(ar_df['appointment_month'])

# Filter from August 2021 onwards
attendance_filtered = ar_df[ar_df['appointment_month'] >= '2021-08']


# Aggregate Attendance by Month
attendance_trend = (
    attendance_filtered
    .groupby(['appointment_month', 'appointment_status'])['count_of_appointments'].sum().reset_index())

import seaborn as sns
import matplotlib.pyplot as plt

# Create the lineplot
plt.figure(figsize = (15, 12))
sns.lineplot(
    data = attendance_trend,
    x = 'appointment_month',
    y = 'count_of_appointments',
    hue = 'appointment_status')

plt.title('Appointment Attendance Outcomes Over Time (2021-08 onwards)')
plt.xlabel('Month')
plt.ylabel('Number of Appointments')
plt.xticks (rotation = 45)

plt.show()

# %% [markdown]
# **Question 4:** Are there changes in terms of appointment type and the busiest months?

# %%
# Create a lineplot to answer the question.
# Convert month to datetime
ar_df['appointment_month'] = pd.to_datetime(ar_df['appointment_month'])

# Filter from August 2021 onwards
appointment_filtered = ar_df[ar_df['appointment_month'] >= '2021-08']


# Aggregate Attendance by Month
appointment_mode = (
    attendance_filtered
    .groupby(['appointment_month', 'appointment_mode'])['count_of_appointments'].sum().reset_index())

import seaborn as sns
import matplotlib.pyplot as plt

# Create the lineplot
plt.figure(figsize = (15, 12))
sns.lineplot(
    data = appointment_mode,
    x = 'appointment_month',
    y = 'count_of_appointments',
    hue = 'appointment_mode')

plt.title('Appointment Mode Outcomes Time (2021-08 onwards)')
plt.xlabel('Month')
plt.ylabel('Number of Appointments')
plt.xticks (rotation = 45)

plt.show()


"""Face to face consultations is the top favourite mode of appointments, even though shows seasonal fluctuations 
whilst telephone appointments which is relatively stable, showed strongly in second position.
Home visits, video/online modes are less popular almost flatlined at the bottom."""
# Out:
# 'Face to face consultations is the top favourite mode of appointments, even though shows seasonal fluctuations \nwhilst telephone appointments which is relatively stable, showed strongly in second position.\nHome visits, video/online modes are less popular almost flatlined at the bottom.'

# %% [markdown]
# **Question 5:** Are there any trends in time between booking an appointment?

# %%
# Conver month to datetime
ar_df['appointment_month'] = pd.to_datetime(ar_df['appointment_month'])


# Filter from August 2021 onwards
waiting_time_filtered = ar_df[ar_df['appointment_month'] >= '2021-08']

# Aggregate by Month and Waiting Category
waiting_time_category = (
    waiting_time_filtered
    .groupby(['appointment_month',
              'time_between_book_and_appointment'])
    ['count_of_appointments'].sum().reset_index())

# %%
# Create a lineplot to answer the question.
# Create the lineplot
plt.figure(figsize = (15, 12))
sns.lineplot(
    data = waiting_time_category,
    x = 'appointment_month',
    y = 'count_of_appointments',
    hue = 'time_between_book_and_appointment')
    

plt.title('Waiting Time Between Booking and Appointment Attendance (2021-08 onwards)')
plt.xlabel('Month')
plt.ylabel('Number of Appointments')
plt.xticks (rotation = 45)
plt.tight_layout()

plt.show()

# %% [markdown]
# **Observations:** From the graph, most appointmemnts are within 0 - 7 days. This is dominated by Same Day appointments,
# followed by 2 -7 Days. This shows that majority of appointments were delivered within short timeframes following booking,
# showing generally responsive access to primary care services. Even though longer waiting categories were observed, the system
# is generally easily accessible.

# %% [markdown]
# **Question 6:** How does the spread of service settings compare?

# %%
# Let's go back to the national category DataFrame you created in an earlier assignment activity.
nc_df = pd.read_excel('national_categories.xlsx')

nc_df.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Create a new DataFrame consisting of the month of appointment and the number of appointments.
nc_new = nc_df[['appointment_month', 'count_of_appointments', 'service_setting']]

# View the DataFrame.
nc_new
# Out:
#        appointment_month  count_of_appointments            service_setting
# 0                2021-08                      3       Primary Care Network
# 1                2021-08                      7                      Other
# 2                2021-08                     79           General Practice
# 3                2021-08                    725           General Practice
# 4                2021-08                      2           General Practice
# ...                  ...                    ...                        ...
# 817389           2022-06                     12  Extended Access Provision
# 817390           2022-06                      4  Extended Access Provision
# 817391           2022-06                     92  Extended Access Provision
# 817392           2022-06                      4  Extended Access Provision
# 817393           2022-06                     19  Extended Access Provision
#
# [817394 rows x 3 columns]

# %%
# Create a boxplot to investigate the spread of service settings.
# Convert month to datetime
nc_new['appointment_month'] = pd.to_datetime(nc_new['appointment_month'])

# Create the boxplot
plt.figure(figsize = (15, 12))
sns.boxplot(
    data = nc_new,
    x = 'appointment_month',
    y = 'count_of_appointments',
    hue = 'service_setting')

plt.title('Distribution of Appointments Across Service Settings by Month (2021-08 onwards)')
plt.xlabel('Month')
plt.ylabel('Number of Appointments')
plt.xticks (rotation = 45)
plt.tight_layout()

plt.show()

# %%
# Create a boxplot to investigate the service settings without GP.
# Filter out GeneralPractice
nc_no_gp = nc_new[nc_new['service_setting'] != 'General Practice']

# Create the boxplot
plt.figure(figsize = (15, 12))
sns.boxplot(
    data = nc_no_gp,
    x = 'appointment_month',
    y = 'count_of_appointments',
    hue = 'service_setting')

plt.title('Distribution of Appointments Across Service Settings (NO GP) by Month (2021-08 onwards)')
plt.xlabel('Month')
plt.ylabel('Number of Appointments')
plt.xticks (rotation = 45)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Provide a summary of your findings and recommendations based on the analysis.

# %% [markdown]
# **Patterns and Trends**
# From the charts, the three (3) broad areas of problems facing the NHS have been investigated and key findings communicated. This section will highlight the prominent patterns and trends as observed.
# - On the volume of appointments, there is sustained high utilisation across the period. There were no prolonged upward/downward trends. Demand for appointments remained stable.
# - There is evidence of seasonal pattern. This peaks in Oct -Nov 2021 and March 2022, but drops in Dec & April. This seasonal fluctuation is consistent with winter pressure and holiday season effects.
# - A pattern of resiliency within the system was observed. There were no long-term decline and the system bounces back quickly after very dip.
# - Another pattern observed is high volatility within the GP practices. This could be the result of location population density (urban vrs rural). This observation requires further investigation as the dataset is silent on population metrics.
#
# **Conclusion & Recommendations**
# In response to the problem statement, the following has been suggested based on the analysis outcomes:
# - Currently, resource utilisation is optimum. No evidence of severe under-utilisation or collapse of services due to high demand.
# - Capacity utilisation is within the NHS guidelines. No compelling evidence to increase staffing levels.
# - Most appointments are attended. The few missed appointments require further investigation. The circa 100000/month missed appointments may be considered high under certain conditions
# - No evidence of worsening backlog of appointments. Most waiting time are within 1-week.
# - Dominant national issue is #healthcare. Policy makers need to pay attention
# - The NHS is GP centric and all other service providers play a supporting role

# %% [markdown]
# > ***Check*** that you have adequately satisfied the expectations of the current module and that you have added code comments as well as Markdown cells documenting your analytic journey and observations to satisfy the assessment criteria.

# %% [markdown]
# **Question 4b:** Identify the busiest months

# %%
# Busiest months
monthly_totals = (
    appointment_filtered
    .groupby('appointment_month')['count_of_appointments'].sum().reset_index())

# Identify peak month
monthly_totals.sort_values(
    'count_of_appointments', ascending = False).head()

# %%
# Busiest months
monthly_totals = (
    appointment_filtered
    .groupby('appointment_month')['count_of_appointments'].sum().reset_index())

# Identify peak month
monthly_totals.sort_values(
    'count_of_appointments', ascending = False)
# Out:
#    appointment_month  count_of_appointments
# 3         2021-11-01               30405070
# 2         2021-10-01               30303834
# 7         2022-03-01               29595038
# 1         2021-09-01               28522501
# 9         2022-05-01               27495508
# 10        2022-06-01               25828078
# 5         2022-01-01               25635474
# 6         2022-02-01               25355260
# 4         2021-12-01               25140776
# 8         2022-04-01               23913060
# 0         2021-08-01               23852171

# %% [markdown]
# The busiest months include October and November when winter pressures begin to buildup.
# The quieter months include December (especially during the Christmas holidays). Also
# during April, the Easter holidays dips activity levels as well as late Summer season.
